# %%
# Imports
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import geopy.distance
from tqdm import tqdm
import numpy as np
import shapely
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Load the data
US = gpd.read_file('US_States/gz_2010_us_040_00_500k.shp')
Canada = gpd.read_file('canada_provinces/canada_provinces.geojson')

AT_profile = np.genfromtxt('AT_profile.csv', delimiter=',')
end_locations = np.genfromtxt("end_locations.csv", delimiter=',')
end_locations = gpd.GeoDataFrame(geometry=\
                gpd.points_from_xy(end_locations[:,1], end_locations[:,0]))
end_miles = np.genfromtxt('end_miles.txt')

daily_distances = np.ones(len(end_miles))*(end_miles[0] + 8.8)
daily_distances[1:] = np.diff(end_miles)
end_locations['Distance'] = daily_distances

end_indecies = np.zeros(len(end_miles)+1)
for i in range(len(end_miles)):
    end_indecies[i+1] = np.abs(AT_profile[:,0] - end_miles[i]).argmin()
end_indecies = end_indecies.astype(int)

US_rot = US.rotate(30, origin=(41, 76))
Canada_rot = Canada.rotate(30, origin=(41, 76))
AT_rot = AT.rotate(30, origin=(41, 76))
end_locations_rot = end_locations.rotate(30, origin=(41, 76))
end_locations_rot = gpd.GeoDataFrame(geometry=end_locations_rot)
end_locations_rot['Distance'] = daily_distances

# %%
# Test display
fig, ax = plt.subplots(figsize=(12,12))
ax.set(xlim=(-85, -67), ylim=(34,47), aspect='equal', facecolor='#FDF1DB')
US.plot(ax=ax, color='#CDC0B0', edgecolor='#5A493F', zorder=0)
Canada.plot(ax=ax, color='#CDC0B0', edgecolor='#5A493F', zorder=1)
AT.plot(ax=ax, color='#715B46', linewidth=4, zorder=2)
end_locations.plot(ax=ax, column='Distance', cmap='jet', \
                   vmin=10, vmax=25, marker='*', markersize=3, zorder=3)

xmin, ymin, xmax, ymax= -85, 33, -65, 47
n_cells = 10
cell_size = (xmax-xmin)/n_cells
grid_cells = []
for x0 in np.arange(xmin, xmax+cell_size, cell_size ):
    for y0 in np.arange(ymin, ymax+cell_size, cell_size):
        # bounds
        x1 = x0-cell_size
        y1 = y0+cell_size
        grid_cells.append(shapely.geometry.box(x0, y0, x1, y1)  )
cell = gpd.GeoDataFrame(grid_cells, columns=['geometry'])
# cell.plot(ax=ax, facecolor="none", edgecolor='#9B7D5B', alpha=0.3, linewidth=1)
# plt.savefig('first_map.png', dpi=80)

# %%
# Make annotated map

background_color = '#FDF1DB'
land_color = '#CDC0B0'
boundary_color = '#7b888f'
arrow_color = '#5A493F'
text_color = 'k'
save_name = 'colors6'


plt.rcParams['text.color'] = text_color
plt.rcParams['axes.labelcolor'] = text_color
plt.rcParams['xtick.color'] = text_color
plt.rcParams['ytick.color'] = text_color

fig, ax = plt.subplots(figsize=(18,24), facecolor=background_color)
ax.set(xlim=(-48, -33), ylim=(-23,-3),aspect='equal', facecolor=background_color)
divider = make_axes_locatable(ax)
cax = divider.append_axes("left", size="5%", pad="2%")


US_rot.plot(ax=ax, color=land_color, edgecolor=boundary_color, zorder=0)
ax.set_axis_off()
# Canada_rot.plot(ax=ax, color='#CDC0B0', edgecolor=arrow_color, zorder=1)

AT_rot.plot(ax=ax, color='w', linewidth=1, zorder=2) #color='#715B46'

im = end_locations_rot.plot(ax=ax, column='Distance', cmap='winter', \
                   vmin=8, vmax=24, marker='o', markersize=30, zorder=3, \
                    legend=True, legend_kwds={'label': "Daily Miles",
                        'cax':cax, 'orientation':'vertical', 'shrink':0.5})



ax.text(0.97, 0.02, 'A P P A L A C H I A N  T R A I L',\
        transform=ax.transAxes, ha='right', fontstretch='ultra-expanded',\
        fontfamily='Bookman Old Style', fontsize=94, rotation=-90)
ax.text(0.893, 0.01, '132 Days • 2,193.1 Miles • > 450,000\' Elevation • 2,679 Pictures • 3 Pairs of Boots • 2 National Parks • 8 National Forests • 5 \"Zeros" • 18 Resupplies' ,\
        transform=ax.transAxes, ha='right', \
        fontfamily='Bookman Old Style', fontsize=19, rotation=-90)
ax.text(0.86, 0.01, 'March 10-July 19, 2021',\
        transform=ax.transAxes, ha='right', \
        fontfamily='Bookman Old Style', fontsize=42, rotation=-90)
ax.text(0.815, 0.01, 'Credit to family for resupplies, DSA for support and data collation',\
        transform=ax.transAxes, ha='right', \
        fontfamily='Bookman Old Style', fontsize=14, rotation=-90)

#•


####
best=(0.25,0.87)
a = end_locations_rot['geometry'][107].coords.xy
ax.annotate('Best Days\non Trail', (a[0][0], a[1][0]), xytext=best, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][108].coords.xy
ax.annotate('Best Days\non Trail', (a[0][0], a[1][0]), xytext=best, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
           fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][109].coords.xy
ax.annotate('Best Days\non Trail', (a[0][0], a[1][0]), xytext=best, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][110].coords.xy
ax.annotate('Best Days\non Trail', (a[0][0], a[1][0]), xytext=best, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))
####

a = end_locations_rot['geometry'][100].coords.xy
ax.annotate('Hiked\nwith Dad', (a[0][0], a[1][0]), xytext=(0.19,0.82), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][101].coords.xy
ax.annotate('Hiked\nwith Dad', (a[0][0], a[1][0]), xytext=(0.19,0.82), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))



a = end_locations_rot['geometry'][38].coords.xy
ax.annotate('Milky Way\nView', (a[0][0], a[1][0]), xytext=(0.57,0.22), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][120].coords.xy
ax.annotate('Milky Way\nView, hiked\nthru night', (a[0][0], a[1][0]), xytext=(0.72,0.83), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.2"))

####
a = end_locations_rot['geometry'][113].coords.xy
ax.annotate('Worst Days\non Trail', (a[0][0], a[1][0]), xytext=(0.65,0.76), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][114].coords.xy
ax.annotate('Worst Days\non Trail', (a[0][0], a[1][0]), xytext=(0.65,0.76), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][115].coords.xy
ax.annotate('Worst Days\non Trail', (a[0][0], a[1][0]), xytext=(0.65,0.76), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][116].coords.xy
ax.annotate('Worst Days\non Trail', (a[0][0], a[1][0]), xytext=(0.65,0.76), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))


a = end_locations_rot['geometry'][88].coords.xy
ax.annotate('Hottest Day \n(98deg)', (a[0][0], a[1][0]), xytext=(0.62,0.6), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][82].coords.xy
ax.annotate('Longest Day \n(30.9mi)', (a[0][0], a[1][0]), xytext=(0.55,0.55), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))


a = end_locations_rot['geometry'][80].coords.xy
ax.annotate('Saw Ziggy', (a[0][0], a[1][0]), xytext=(0.55,0.48), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))


a = end_locations_rot['geometry'][93].coords.xy
ax.annotate('Saw Mom', (a[0][0], a[1][0]), xytext=(0.66,0.64), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='bottom',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][55].coords.xy
ax.annotate('Hiked in Adidas\nSlides (The Priest)', (a[0][0], a[1][0]), xytext=(0.63,0.29), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.3"))

a = end_locations_rot['geometry'][73].coords.xy
ax.annotate('Flattest Day', (a[0][0], a[1][0]), xytext=(0.56,0.42), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.3"))


a = end_locations_rot['geometry'][57].coords.xy
ax.annotate('Got J&J COVID\nVaccine', (a[0][0], a[1][0]), xytext=(0.56,0.35), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))


####
sister = (0.55,0.18)
a = end_locations_rot['geometry'][43].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][44].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][45].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][46].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][47].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][48].coords.xy
ax.annotate('Hiked with\nSister', (a[0][0], a[1][0]), xytext=sister, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))
####

a = end_locations_rot['geometry'][79].coords.xy
ax.annotate('Scariest Climb\n(Lehigh Gap)', (a[0][0], a[1][0]), xytext=(0.04,0.63), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))


a = end_locations_rot['geometry'][66].coords.xy
ax.annotate('Favorite River\n(Potomac)', (a[0][0], a[1][0]), xytext=(0.03,0.57), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][131].coords.xy
ax.annotate('Top 3\nSummit\n(Katahdin)', (a[0][0], a[1][0]), xytext=(0.69,0.96), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.2"))

a = end_locations_rot['geometry'][110].coords.xy
ax.annotate('Top 3\nSummit\n(Madison)', (a[0][0], a[1][0]), xytext=(0.43,0.9), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][26].coords.xy
ax.annotate('Top 3\nSummit\n(Unaka)', (a[0][0], a[1][0]), xytext=(0.02, 0.5), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.2"))


a = end_locations_rot['geometry'][15].coords.xy
ax.annotate('Scariest Day\n("The Sawteeth"\nThunderstorm)', (a[0][0], a[1][0]), xytext=(0.45,0.04), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

####
a = end_locations_rot['geometry'][12].coords.xy
ax.annotate('Almost Quit', (a[0][0], a[1][0]), xytext=(0.48,0.09), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

a = end_locations_rot['geometry'][35].coords.xy
ax.annotate('Almost Quit', (a[0][0], a[1][0]), xytext=(0.48,0.09), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.1"))
####


####
animals=(0.14,0.72)
# Ponies 1
a = end_locations_rot['geometry'][35].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=3, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.25"))
# Ponies 2
a = end_locations_rot['geometry'][36].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=3, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.2"))

# Waynesboro bear
a = end_locations_rot['geometry'][57].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=.2"))

# Zoo bears
a = end_locations_rot['geometry'][86].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

# Dalton bear
a = end_locations_rot['geometry'][94].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

# Smarts mtn bear
a = end_locations_rot['geometry'][105].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

# Monson moose
a = end_locations_rot['geometry'][123].coords.xy
ax.annotate('Large Animal\nEncounters\n(Wild Ponies,\nBear,or Moose)', (a[0][0], a[1][0]), xytext=animals, \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top', alpha=0,\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))
####


a = end_locations_rot['geometry'][22].coords.xy
ax.annotate('Coldest Day\n(7deg)', (a[0][0], a[1][0]), xytext=(0.51,0.14), \
            textcoords='axes fraction', fontfamily='Bookman Old Style', \
            fontsize=14, fontstyle='italic', ha='center', va='top',\
            arrowprops=dict(arrowstyle='->', shrinkB=5, \
            fc=arrow_color, ec=arrow_color, \
            connectionstyle="arc3,rad=-.2"))

cax.yaxis.set_ticks_position('left')
cax.yaxis.set_label_position('left')
plt.tight_layout(pad=1.2)
# fig.savefig('final_fig.pdf', facecolor=fig.get_facecolor(), edgecolor='none', dpi=100)

# %%
fig, axs = plt.subplots(nrows=33, ncols=4, sharex=True, figsize=(24,18), facecolor='#FDF1DB')
col = 0
for i in range(131):
    a = i % 33
    if i % 33 == 0 and i > 0:
        col += 1

    axs[a, col].set(xlim=(0, 32), ylim=(-2000, 8000), yticks=[], facecolor='#717e85')#, aspect=(1/3000))
    if len(AT_profile[end_indecies[i]:end_indecies[i+1], 0]) == 0:
        continue
    x = AT_profile[end_indecies[i]:end_indecies[i+1], 0] - \
                min(AT_profile[end_indecies[i]:end_indecies[i+1], 0])
    y = AT_profile[end_indecies[i]:end_indecies[i+1], 1]
    axs[a, col].plot(x, y, color='k')
    axs[a, col].fill_between(x, y, color='#ad9150')
    axs[a, col].fill_between(x, y, 7000, color='#5faed9')
    


# Last row
axs[-1,-1].set(xlim=(0, 32), ylim=(-2000, 8000), yticks=[], facecolor='#717e85')
x = AT_profile[end_indecies[-2]:end_indecies[-1], 0] - \
                min(AT_profile[end_indecies[-2]:end_indecies[-1], 0])
y = AT_profile[end_indecies[-2]:end_indecies[-1], 1]
axs[-1,-1].plot(x, y, color='k')
axs[-1,-1].fill_between(x, y, color='#ad9150')
axs[-1,-1].fill_between(x, y, 7000, color='#5faed9')


axs[-1,-1].annotate('D a i l y  E l e v a t i o n  P r o f i l e s',
            xy=(.5, .07), xycoords='figure fraction', weight='bold',
            horizontalalignment='center',
            fontfamily='Bookman Old Style',
            fontsize=48)

axs[-1,-1].annotate('Chronological top to bottom, wrapping bottom of column to top of next',
            xy=(.5, .04), xycoords='figure fraction',
            horizontalalignment='center',
            fontfamily='Bookman Old Style',
            fontsize=18)

axs[-1,-1].annotate('Each subplot bounded vertically by absolute elevation {-2000, 8000} feet, horizontally by {0,30} miles on trail',
            xy=(.5, .02), xycoords='figure fraction',
            horizontalalignment='center',
            fontfamily='Bookman Old Style',
            fontsize=18)

plt.subplots_adjust(left=0.01, bottom=0.13, right=0.99, top=0.99, wspace=0.03, hspace=0.01)
fig.savefig('final_profiles.png', facecolor=fig.get_facecolor(), edgecolor='none', dpi=100)

# %%
# Quick sketch of the whole trail profile
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(AT_profile[:,0], AT_profile[:,1])
ax.set(xlabel='Trail Miles', ylabel='Elevation')
# Out:
# [Text(0, 0.5, 'Elevation'), Text(0.5, 0, 'Trail Miles')]
